# %% [markdown]
# # Airbnb Price Prediction

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing our dataset

# %%
data = pd.read_csv('airbnb_top_cities.csv') #importing the dataset
data.head() #display the first 5 rows of the dataset
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16420\1124383373.py:1: DtypeWarning: Columns (4,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('airbnb_top_cities.csv') #importing the dataset
#       id                                               name  host_id  \
# 0  13913                Holiday London DB Room Let-on going    54730
# 1  15400                Bright Chelsea  Apartment. Chelsea!    60302
# 2  17402   Very Central Modern 3-Bed/2 Bath By Oxford St W1    67564
# 3  24328                   Battersea live/work artist house    41759
# 4  36274  Bright 1 bedroom apt off brick lane in Shoreditch   133271
#
#   host_name neighbourhood_group           neighbourhood  latitude  longitude  \
# 0     Alina                 NaN               Islington  51.56861   -0.11270
# 1  Philippa                 NaN  Kensington and Chelsea  51.48780   -0.16813
# 2       Liz                 NaN             Westminster  51.52195   -0.14094
# ...

# %%
data.tail() #display the last 5 rows in the dataset
# Out:
#                          id  \
# 292797  1480042219847997681
# 292798  1480050997732404756
# 292799  1480052704340595354
# 292800  1480144278899031973
# 292801  1480493397212908710
#
#                                                      name    host_id  \
# 292797     Rustica Cove—Heritage Escape by Manly’s Shores  347608321
# 292798      Modern Family Home In Paddington - 3 bedrooms   16026854
# 292799                     Top Floor APT in heart of City   21151187
# 292800                   Two-bedroom standalone townhouse  711457600
# 292801  Central Burwood 2Beds | Walk to Westfield & Train  659806489
#
#                                   host_name neighbourhood_group neighbourhood  \
# 292797                                Calyn                 NaN         Manly
# 292798  Tracey McArdle Exclusive Properties                 NaN     Woollahra
# 292799                                 John                 NaN        Sydney
# ...

# %%
data.columns #display the columns in the dataset
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'city',
#        'scrape_date'],
#       dtype='object')

# %%
data.dtypes #display the datatypes of each column
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# city                               object
# scrape_date                        object
# dtype: object

# %%
data.info() #display info about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292802 entries, 0 to 292801
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              292802 non-null  int64
#  1   name                            292802 non-null  object
#  2   host_id                         292802 non-null  int64
#  3   host_name                       292712 non-null  object
#  4   neighbourhood_group             19410 non-null   object
#  5   neighbourhood                   292802 non-null  object
#  6   latitude                        292802 non-null  float64
#  7   longitude                       292802 non-null  float64
#  8   room_type                       292802 non-null  object
#  9   price                           139950 non-null  float64
#  10  minimum_nights                  292802 non-null  int64
#  11  number_of_reviews               292802 non-null  int64
# ...

# %%
data.describe() #display a statistical summary of the numericl columns in the data
# Out:
#                  id       host_id       latitude      longitude         price  \
# count  2.928020e+05  2.928020e+05  292802.000000  292802.000000  1.399500e+05
# mean   6.925516e+17  2.169006e+08      40.009043      21.583817  6.042208e+02
# std    5.785082e+17  2.219687e+08      21.677901      43.996214  7.403676e+03
# min    2.737000e+03  1.662000e+03     -34.095680      -0.496760  4.000000e+00
# 25%    3.347211e+07  2.495756e+07      41.878008      -0.066950  9.400000e+01
# 50%    8.724348e+17  1.180033e+08      48.866320       2.335690  1.630000e+02
# 75%    1.208697e+18  4.221622e+08      51.495854      12.463966  3.420000e+02
# max    1.518168e+18  7.206394e+08      52.425120     151.340140  1.085147e+06
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count   292802.000000      292802.000000      226437.000000
# mean        18.515328          31.822187           1.169245
# std         65.016518          73.409545           1.535733
# ...

# %%
data.shape #the dataset has 292802 rows and 20 coluumns
# Out:
# (292802, 20)

# %% [markdown]
# ## Checking for Missing Values

# %%
data.isnull().sum() #checking the columns with missing values
# Out:
# id                                     0
# name                                   0
# host_id                                0
# host_name                             90
# neighbourhood_group               273392
# neighbourhood                          0
# latitude                               0
# longitude                              0
# room_type                              0
# price                             152852
# minimum_nights                         0
# number_of_reviews                      0
# last_review                        66365
# reviews_per_month                  66365
# calculated_host_listings_count         0
# availability_365                       0
# number_of_reviews_ltm                  0
# license                           152949
# city                                   0
# scrape_date                            0
# dtype: int64

# %% [markdown]
# The columns with missing values are host_name,neighbourhood_group,price,last_review,reviews_per_month and license.
#
# Remembering that the key focus of the project is predicting the price of an airbnb, with the price being our target. Since our data has 292,802 rows and 152,852 rows with null values in the price column, I decided to drop the null values in price, instead of filling the price target with measures of central tendencies, because our model would learn our 'imputed' prices instead of learning the actual price trends.
#
# I also decided to drop the neighborhood_group,last_review,reviews_per_month and license columns as they don't have much significance to the price prediction.
#
# I also filled missing values in host_name with a placeholder 'Unknown'

# %% [markdown]
# #### Dropping columns
# ##### 'neighbourhood_group','last_review','reviews_per_month','license'

# %%
data = data.drop(columns=['neighbourhood_group','last_review','reviews_per_month','license'])
#remove the above 4 columns

# %%
data.shape #confirming that the 4 columns have been dropped
# Out:
# (292802, 16)

# %% [markdown]
# #### Dropping rows with missing values in the Price column

# %%
data = data.dropna(subset=['price'])
data.isnull().sum() #confirming that the price column doesn't have any missing values
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                         47
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# availability_365                   0
# number_of_reviews_ltm              0
# city                               0
# scrape_date                        0
# dtype: int64

# %% [markdown]
# #### Filling missing values in host_name column with placeholder 'Unknown'

# %%
data['host_name'] = data['host_name'].fillna('Unknown')

# %%
data.isnull().sum() #confirming that there are no missing values in the data
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# city                              0
# scrape_date                       0
# dtype: int64

# %% [markdown]
# ### Checking for Duplicates

# %%
data.duplicated().sum() #checking for any duplicates
# Out:
# np.int64(0)

# %% [markdown]
# ### Checking for Outliers

# %%
#boxplot visualization to check for outliers
sns.boxplot(x=data['price'])
plt.title('Boxplot of Airbnb Prices')
plt.show()

# %%
data['price'].max() #check the maximum price in the price column
# Out:
# 1085147.0

# %%
data['price'].min() #check the minimum price in the price column
# Out:
# 4.0
